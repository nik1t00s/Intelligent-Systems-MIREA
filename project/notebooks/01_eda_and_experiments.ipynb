# %% [markdown]
# # Устаревший notebook
#
# Этот файл оставлен только для совместимости со старой структурой репозитория.
#
# Актуальный EDA находится в `notebooks/01_eda.ipynb`.
#
# Актуальный notebook с моделированием и таблицей метрик находится в `notebooks/02_modeling.ipynb`.
#
# Финальный проект использует реальный Jira Dataset, а не синтетические данные.
